-- %%
---Query 1: Viewing the first 100 rows of the table
select *
from `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2` 


---Query 2: Viewing distinct values in the store location colunm
Select distinct store_location
from `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


---Query 3: This query groups by store location
Select distinct store_location,
               sum (transaction_qty*unit_price) AS Store_Reveue
from `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2` 
Group by store_location;

---Query 4: Using a column alias
Select product_category AS Category,
       unit_price AS Product_Price
FROM `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


---Query 5: Filtering using where
Select*
From `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`
Where product_category = 'Coffee';


---Query 6: Filtering using where and AND
Select*
From `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`
Where product_category = 'Coffee' and store_location = 'Lower Manhattan';


---Query 7: Fining the minimum unit price 
Select *
From `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`
Where product_category = 'Coffee beans' 
AND unit_price>10;


---Query 8 : Finding Maximum unit price
Select Max( Unit_price) AS Max_Price
From `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


---Query 9 : Filtering using Where and OR
Select*
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`
Where product_category ='Coffee'
Or product_category = 'Tea';


----Query 10: Filtering using Where and In
Select*
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`
Where product_category IN ('Coffee','Tea');


---Query 12 : Counting total transactions
Select count (*)
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


---Query 13 : Calculate total sales
Select sum (transaction_qty*unit_price) AS Total_Sales
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


---Query 14 : Calculate minimum and maximum price
Select min (unit_price) AS cheapest_item,
       max (unit_price) AS most_expensive_item
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


---Query 15 : Total sales per category descending
Select product_category,
      sum (transaction_qty*unit_price) AS Total_Sales
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`
Group by product_category
Order by Total_Sales DESC;


---Query 16 : Extracting month and weekday
Select 
    month(to_date(transaction_date, 'M/d/yyyy')) AS month,
    date_format(to_date(transaction_date, 'M/d/yyyy'), 'EEEE') AS weekday
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


--- Query 17 : Checking date range
Select MIN(transaction_date) AS min_date, 
       MAX(transaction_date) AS latest_date 
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


----Query 18 : Checking names of different stores

Select Distinct store_location
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;

-------
Select COUNT(Distinct store_id) AS number_of_stores
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


----Query 19 : Checking products sold at stores
Select Distinct product_category
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;

----
Select Distinct product_detail
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;

---
Select Distinct product_type
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;

----
Select Distinct product_category AS category,
                product_detail AS product_name
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


----Query 20 : Checking products prices

Select MIN(unit_price) As cheapest_price
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;

------
Select MAX(unit_price) As expensive_price
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


---Query 21 : Counting rows, sales, products and sores
Select 
      COUNT(*) AS number_of_rows,
      COUNT(Distinct transaction_id) AS number_of_sales,
      COUNT(Distinct product_id) AS number_of_products,
      COUNT(Distinct store_id) AS number_of_stores
    
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


----Query 22 : Extracting daynamne and month name form transaction date
Select transaction_id,
       transaction_date,
       Dayname(transaction_date) AS Day_name,
       Monthname(transaction_date) AS Month_name,
       SUM(transaction_qty*unit_price) AS revenue_per_day
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


-----Query 23 : Extracting revenue and grouping by dayname to have revenu generated per day
Select COUNT(*)
From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`;


----------Query 24 : Testing Big query
Select 
      transaction_date,
      dayname(transaction_date) AS Day_name,
      monthname(transaction_date) AS Month_name,
      date_format(transaction_time, 'HH:mm:ss') AS purchase_time,
      dayofmonth (transaction_date) AS day_of_month,


Case
      When date_format(transaction_time, 'HH:mm:ss') between '00:00:00' and '11:59:59' then '01.Morning'
      When date_format(transaction_time, 'HH:mm:ss') between '12:00:00' and '16:59:59' then '02.Afternoon'
      When date_format(transaction_time, 'HH:mm:ss') >= '17:00:00' then '03.Evening'
      End as time_buckets,

      Case
      When dayname(transaction_date) IN ('Sun', 'Sat') THEN 'Weekend'
      ELSE 'Weekday'
      End as Day_classification,

Case 
When (transaction_qty*unit_price) <=100 THEN '01.Low spender'
When (transaction_qty*unit_price) BETWEEN 101 AND 200 THEN '02.Medium spender'
When (transaction_qty*unit_price) BETWEEN 201 AND 300 THEN '03.High spender'
Else '04.Extreme spender'
   End As spending_buckets,
      
      COUNT(Distinct transaction_id) AS number_of_sales,
      COUNT(Distinct product_id) AS number_of_products,
      COUNT(Distinct store_id) AS number_of_stores,
  
      SUM(transaction_qty*unit_price) AS revenue_per_day
   
   From  `workspace`.`default`.`1771947879858_bright_coffee_shop_sales_2_2`

Group by transaction_date,
         Day_name,
        spending_buckets,
         Month_name,
         store_location,
         product_category,
         purchase_time,
         time_buckets,
         day_of_month,
         Day_classification,
         product_detail;
